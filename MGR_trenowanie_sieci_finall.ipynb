# %% [markdown]
# # Trenowanie sieci
# ## Inicjalizacja środowiska

# %%
#!apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !apt-get install -y -qq software-properties-common module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 130963 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.6-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.6-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.6-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# ...

# %% [markdown]
# ## Mapowanie dysku GDrive do Colab Local Storage

# %%
# !mkdir -p gdrive
# !google-drive-ocamlfuse gdrive
print("Done!")
# Out:
# Done!

# %% [markdown]
# ## Klonowanie i konfiguracja Mask R-CNN Matterport

# %%
# !git clone https://github.com/matterport/Mask_RCNN.git 
print("GOTOWE")
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 119.41 MiB | 46.37 MiB/s, done.
# Resolving deltas: 100% (569/569), done.
# GOTOWE

# %%
# %pwd

# %%
# !mkdir Mask_RCNN/samples/znaki
#!rm /content/Mask_RCNN/samples/znaki/znaki.py
# !cp /content/gdrive/MGR_RCNN/ZNAKI/znaki.py /content/Mask_RCNN/samples/znaki/znaki.py
# Out:
# mkdir: cannot create directory ‘Mask_RCNN/samples/znaki’: No such file or directory

# %%
import os,sys

# Root directory of the project
ROOT_DIR = os.path.abspath("/content/Mask_RCNN/")
MGR_RCNN = os.path.abspath('/content/gdrive/MGR_RCNN/')

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
sys.path.append(MGR_RCNN)

# %%
# %cd Mask_RCNN
# !pip3 install -r requirements.txt
# !pip3 install imgaug

# %%
# !python setup.py install

# %% [markdown]
# # Trenowanie sieci
#
# Trenowanie bylo wznawiane kilkukrotnie za każdym razem wznawiane od miejsca (epoki) na której się skończyło. Pierwsze wywołanie - inicjacja wagami COCO.

# %%
# %cd /content/Mask_RCNN/samples/znaki/
# !python znaki.py train --dataset=/content/gdrive/MGR_RCNN/dataset/ --weights=coco
# Out:
# /content/Mask_RCNN/samples/znaki
# Using TensorFlow backend.
# Weights:  coco
# Dataset:  /content/gdrive/MGR_RCNN/dataset/
# Logs:  /content/gdrive/MGR_RCNN/COCO/logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1408
# IMAGE_META_SIZE                56
# IMAGE_MIN_DIM                  832
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1408 1408    3]
# LEARNING_MOMENTUM              0.9
# ...

# %%
# !cp /content/Mask_RCNN/logs/znaki20190707T1347/mask_rcnn_znaki_0030.h5 /content/gdrive/MGR_RCNN/CP/

# %%
# !ls /content/gdrive/MGR_RCNN/CP/

# %% [markdown]
# ## Testy detekcji

# %%
# !python3 znaki.py splash --weights=/content/gdrive/MGR_RCNN/COCO/logs/znaki20190708T2020/mask_rcnn_znaki_0160.h5 --image=/content/gdrive/MGR_RCNN/dataset/val/00801.ppm
# Out:
# Using TensorFlow backend.
# Weights:  /content/gdrive/MGR_RCNN/COCO/logs/znaki20190708T2020/mask_rcnn_znaki_0160.h5
# Dataset:  None
# Logs:  /content/gdrive/MGR_RCNN/COCO/logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1408
# IMAGE_META_SIZE                56
# IMAGE_MIN_DIM                  832
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1408 1408    3]
# LEARNING_MOMENTUM              0.9
# ...
